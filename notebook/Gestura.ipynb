# %% [markdown]
# # Importing Libraries

# %%
import cv2
from ultralytics import YOLO
import matplotlib.pyplot as plt
from googletrans import Translator
import pyttsx3
from gtts import gTTS

# %%
import gtts as gt 
import os
 
TamilText="வணக்கம்.அறம் செய விரும்பு, ஆறுவது சினம், இயல்வது கரவேல், ஈவது விலக்கேல், உடையது விளம்பேல். நன்றி!"
tts = gt.gTTS(text=TamilText, lang='ta')
tts.save("Tamil-Audio.mp3")
os.system("Tamil-Audio.mp3")
# Out:
# 0

# %%
import gtts as gt 
import pygame
from io import BytesIO

TamilText="வணக்கம்.அறம் செய விரும்பு, ஆறுவது சினம், இயல்வது கரவேல், ஈவது விலக்கேல், உடையது விளம்பேல். நன்றி!"
tts = gt.gTTS(text=TamilText, lang='ta')

# Save audio to a BytesIO object
audio_bytes = BytesIO()
tts.write_to_fp(audio_bytes)
audio_bytes.seek(0)

# Initialize pygame mixer
pygame.mixer.init()
pygame.mixer.music.load(audio_bytes)
pygame.mixer.music.play()

# Wait for the audio to finish playing
while pygame.mixer.music.get_busy():
    pygame.time.Clock().tick(10)
# Out:
# pygame 2.5.2 (SDL 2.28.3, Python 3.10.3)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %% [markdown]
# # Google Translator

# %%
from googletrans import Translator
import pyttsx3

def translate_and_speak(text, target_language):
    # Translate text to the target language
    translator = Translator()
    translated_text = translator.translate(text, dest=target_language).text

    # Initialize the pyttsx3 engine
    engine = pyttsx3.init()

    # Convert the translated text to speech
    try:
        engine.say(translated_text)
        engine.runAndWait()
    except Exception as e:
        print(f"Error during text-to-speech conversion: {e}")

text_to_translate = "Hello, srihari."
translate_and_speak(text_to_translate, 'ta')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 20
#      17         print(f"Error during text-to-speech conversion: {e}")
#      19 text_to_translate = "Hello, srihari."
# ---> 20 translate_and_speak(text_to_translate, 'ta')
#
# Cell In[5], line 7, in translate_and_speak(text, target_language)
#       4 def translate_and_speak(text, target_language):
#       5     # Translate text to the target language
#       6     translator = Translator()
# ----> 7     translated_text = translator.translate(text, dest=target_language).text
#       9     # Initialize the pyttsx3 engine
#      10     engine = pyttsx3.init()
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\googletrans\client.py:182, in Translator.translate(self, text, dest, src, **kwargs)
#     179     return result
#     181 origin = text
# --> 182 data = self._translate(text, dest, src, kwargs)
#     184 # this code will be updated when the format is changed.
#     185 translated = ''.join([d[0] if d[0] else '' for d in data[0]])
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\googletrans\client.py:78, in Translator._translate(self, text, dest, src, override)
#      77 def _translate(self, text, dest, src, override):
# ---> 78     token = self.token_acquirer.do(text)
#      79     params = utils.build_params(query=text, src=src, dest=dest,
#      80                                 token=token, override=override)
#      82     url = urls.TRANSLATE.format(host=self._pick_service_url())
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\googletrans\gtoken.py:194, in TokenAcquirer.do(self, text)
#     193 def do(self, text):
# --> 194     self._update()
#     195     tk = self.acquire(text)
#     196     return tk
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\googletrans\gtoken.py:62, in TokenAcquirer._update(self)
#      59     return
#      61 # this will be the same as python code after stripping out a reserved word 'var'
# ---> 62 code = self.RE_TKK.search(r.text).group(1).replace('var ', '')
#      63 # unescape special ascii characters such like a \x3d(=)
#      64 code = code.encode().decode('unicode-escape')
#
# AttributeError: 'NoneType' object has no attribute 'group'

# %% [markdown]
# # Weights

# %%
model = YOLO('C:\\Users\\Admin\\OneDrive\\Desktop\\gestura\\gestura\\sign_language.pt')

# %%
classNames = ['additional', 'alcohol', 'allergy', 'bacon', 'bag', 'barbecue', 'bill', 'biscuit', 'bitter', 'bread', 'burger', 'bye', 'cake', 'cash', 'cheese', 'chicken', 'coke', 'cold', 'cost', 'coupon', 'credit card', 'cup', 'dessert', 'drink', 'drive', 'eat', 'eggs', 'enjoy', 'fork', 'french fries', 'fresh', 'hello', 'hot', 'icecream', 'ingredients', 'juicy', 'ketchup', 'lactose', 'lettuce', 'lid', 'manager', 'menu', 'milk', 'mustard', 'napkin', 'no', 'order', 'pepper', 'pickle', 'pizza', 'please', 'ready', 'receipt', 'refill', 'repeat', 'safe', 'salt', 'sandwich', 'sauce', 'small', 'soda', 'sorry', 'spicy', 'spoon', 'straw', 'sugar', 'sweet', 'thank-you', 'tissues', 'tomato', 'total', 'urgent', 'vegetables', 'wait', 'warm', 'water', 'what', 'would', 'yoghurt', 'your']

# %% [markdown]
# ## Image testing

# %%
image = cv2.imread('C:\\Users\\Admin\\OneDrive\\Desktop\\gestura\\gestura\\test3.png')
results = model(image)[0]
translator = Translator()
text_to_speech = pyttsx3.init()
for result in results.boxes.data.tolist():
    x1, y1, x2, y2, score, class_id = result
    word = classNames[int(class_id)]
    translation = translator.translate(word, dest='ta')
    print(translation.text)
    output = translation.text
    try:
        tts = gt.gTTS(text=output, lang='ta')
        audio_bytes = BytesIO()
        tts.write_to_fp(audio_bytes)
        audio_bytes.seek(0)

        # Initialize pygame mixer
        pygame.mixer.init()
        pygame.mixer.music.load(audio_bytes)
        pygame.mixer.music.play()

    except Exception as e:
        print(f"Error during text-to-speech conversion: {e}")
# Out:
# 0: 576x640 1 alcohol, 312.0ms
# Speed: 11.6ms preprocess, 312.0ms inference, 2.1ms postprocess per image at shape (1, 3, 576, 640)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[20], line 8
#       6 x1, y1, x2, y2, score, class_id = result
#       7 word = classNames[int(class_id)]
# ----> 8 translation = translator.translate(word, dest='ta')
#       9 print(translation.text)
#      10 output = translation.text
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\googletrans\client.py:182, in Translator.translate(self, text, dest, src, **kwargs)
#     179     return result
#     181 origin = text
# --> 182 data = self._translate(text, dest, src, kwargs)
#     184 # this code will be updated when the format is changed.
#     185 translated = ''.join([d[0] if d[0] else '' for d in data[0]])
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\googletrans\client.py:78, in Translator._translate(self, text, dest, src, override)
#      77 def _translate(self, text, dest, src, override):
# ---> 78     token = self.token_acquirer.do(text)
#      79     params = utils.build_params(query=text, src=src, dest=dest,
#      80                                 token=token, override=override)
#      82     url = urls.TRANSLATE.format(host=self._pick_service_url())
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\googletrans\gtoken.py:194, in TokenAcquirer.do(self, text)
#     193 def do(self, text):
# --> 194     self._update()
#     195     tk = self.acquire(text)
#     196     return tk
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\googletrans\gtoken.py:62, in TokenAcquirer._update(self)
#      59     return
#      61 # this will be the same as python code after stripping out a reserved word 'var'
# ---> 62 code = self.RE_TKK.search(r.text).group(1).replace('var ', '')
#      63 # unescape special ascii characters such like a \x3d(=)
#      64 code = code.encode().decode('unicode-escape')
#
# AttributeError: 'NoneType' object has no attribute 'group'

# %%
cap = cv2.VideoCapture(0)

while True:
    
    ret, frame = cap.read()
    
    while True:
    
            ret, frame = cap.read()

            results = model(frame, show=True)[0]

            for result in results.boxes.data.tolist():
                x1, y1, x2, y2, score, class_id = result
                word = classNames[int(class_id)]
            
                try:
                    # Initialize the engine only once
                    engine = pyttsx3.init()

                    # Check if the engine's run loop is not already running
                    if not engine._inLoop:
                        voices = engine.getProperty('voices')
                        engine.setProperty('voice', voices[1].id)
                        engine.say(word)
                        engine.runAndWait()
                    else:
                        print("Text-to-speech run loop is already in progress. Wait until it finishes.")
                except Exception as e:
                    print(f"Error during text-to-speech conversion: {e}")

            #cv2.imshow('sample', frame)

            if cv2.waitKey(1) == ord('q'):
                break
    cap.release()
    cv2.destroyAllWindows()
# Out:
# 0: 480x640 (no detections), 70.5ms
# Speed: 2.2ms preprocess, 70.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 12.5ms
# Speed: 5.0ms preprocess, 12.5ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 11.0ms
# Speed: 2.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 10.5ms
# Speed: 4.4ms preprocess, 10.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 9.5ms
# Speed: 2.4ms preprocess, 9.5ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 14.9ms
# Speed: 1.0ms preprocess, 14.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 12.0ms
# Speed: 2.1ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 12.2ms
# Speed: 0.0ms preprocess, 12.2ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 9.1ms
# Speed: 1.0ms preprocess, 9.1ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 9.3ms
# Speed: 2.0ms preprocess, 9.3ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 8.7ms
# Speed: 1.5ms preprocess, 8.7ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 10.2ms
# Speed: 1.0ms preprocess, 10.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 8.7ms
# Speed: 1.5ms preprocess, 8.7ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 12.6ms
# Speed: 2.0ms preprocess, 12.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 9.3ms
# Speed: 1.0ms preprocess, 9.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 8.7ms
# Speed: 2.6ms preprocess, 8.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 9.0ms
# Speed: 2.3ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 10.1ms
# Speed: 1.0ms preprocess, 10.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 9.6ms
# Speed: 1.0ms preprocess, 9.6ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 9.5ms
# Speed: 1.4ms preprocess, 9.5ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 14.2ms
# Speed: 2.1ms preprocess, 14.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 11.4ms
# Speed: 1.0ms preprocess, 11.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 12.4ms
# Speed: 2.0ms preprocess, 12.4ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 10.5ms
# Speed: 2.3ms preprocess, 10.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 8.6ms
# Speed: 2.1ms preprocess, 8.6ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 10.5ms
# Speed: 2.1ms preprocess, 10.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 9.8ms
# Speed: 1.4ms preprocess, 9.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 12.5ms
# Speed: 1.5ms preprocess, 12.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 9.7ms
# Speed: 2.5ms preprocess, 9.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 9.6ms
# Speed: 2.1ms preprocess, 9.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 10.1ms
# Speed: 1.3ms preprocess, 10.1ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 12.9ms
# Speed: 1.9ms preprocess, 12.9ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 9.0ms
# Speed: 1.5ms preprocess, 9.0ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 9.9ms
# Speed: 1.0ms preprocess, 9.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 9.5ms
# Speed: 1.4ms preprocess, 9.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 9.7ms
# Speed: 2.1ms preprocess, 9.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 11.5ms
# Speed: 2.5ms preprocess, 11.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 9.1ms
# Speed: 2.0ms preprocess, 9.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 10.5ms
# Speed: 2.2ms preprocess, 10.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 10.8ms
# Speed: 2.0ms preprocess, 10.8ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 9.5ms
# Speed: 1.0ms preprocess, 9.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 11.8ms
# Speed: 1.0ms preprocess, 11.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 13.1ms
# Speed: 1.0ms preprocess, 13.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 13.1ms
# Speed: 2.3ms preprocess, 13.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 13.5ms
# Speed: 1.4ms preprocess, 13.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 12.7ms
# Speed: 2.2ms preprocess, 12.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 13.0ms
# Speed: 2.4ms preprocess, 13.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 12.8ms
# Speed: 2.2ms preprocess, 12.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 15.9ms
# Speed: 2.4ms preprocess, 15.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 15.8ms
# Speed: 1.4ms preprocess, 15.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 12.8ms
# Speed: 2.4ms preprocess, 12.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 14.5ms
# Speed: 2.0ms preprocess, 14.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 15.3ms
# Speed: 1.0ms preprocess, 15.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 13.5ms
# Speed: 1.5ms preprocess, 13.5ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 15.0ms
# Speed: 2.4ms preprocess, 15.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 13.5ms
# Speed: 2.1ms preprocess, 13.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 13.4ms
# Speed: 1.5ms preprocess, 13.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 14.7ms
# Speed: 1.0ms preprocess, 14.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 13.3ms
# Speed: 2.2ms preprocess, 13.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 14.6ms
# Speed: 2.0ms preprocess, 14.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 14.2ms
# Speed: 2.1ms preprocess, 14.2ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 15.4ms
# Speed: 1.5ms preprocess, 15.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 14.8ms
# Speed: 0.5ms preprocess, 14.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 13.1ms
# Speed: 2.0ms preprocess, 13.1ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 16.1ms
# Speed: 1.0ms preprocess, 16.1ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 15.4ms
# Speed: 0.5ms preprocess, 15.4ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 14.7ms
# Speed: 1.1ms preprocess, 14.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 14.4ms
# Speed: 3.1ms preprocess, 14.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 16.3ms
# Speed: 1.0ms preprocess, 16.3ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 26.6ms
# Speed: 2.5ms preprocess, 26.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bread, 26.0ms
# Speed: 1.3ms preprocess, 26.0ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 31.2ms
# Speed: 2.4ms preprocess, 31.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 31.7ms
# Speed: 2.0ms preprocess, 31.7ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 32.8ms
# Speed: 2.0ms preprocess, 32.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 31.8ms
# Speed: 2.0ms preprocess, 31.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 32.2ms
# Speed: 3.0ms preprocess, 32.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 29.0ms
# Speed: 1.4ms preprocess, 29.0ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 28.1ms
# Speed: 2.0ms preprocess, 28.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 28.6ms
# Speed: 3.0ms preprocess, 28.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 29.0ms
# Speed: 2.0ms preprocess, 29.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 29.6ms
# Speed: 2.0ms preprocess, 29.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 28.3ms
# Speed: 2.0ms preprocess, 28.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 16.4ms
# Speed: 1.6ms preprocess, 16.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 14.9ms
# Speed: 1.2ms preprocess, 14.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 13.1ms
# Speed: 1.0ms preprocess, 13.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 12.5ms
# Speed: 2.0ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 13.5ms
# Speed: 1.0ms preprocess, 13.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 12.3ms
# Speed: 1.0ms preprocess, 12.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 12.0ms
# Speed: 1.9ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 14.9ms
# Speed: 1.0ms preprocess, 14.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 12.5ms
# Speed: 1.0ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 14.0ms
# Speed: 1.0ms preprocess, 14.0ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 15.7ms
# Speed: 1.4ms preprocess, 15.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 12.6ms
# Speed: 1.0ms preprocess, 12.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 12.6ms
# Speed: 1.0ms preprocess, 12.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 13.9ms
# Speed: 2.3ms preprocess, 13.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 13.0ms
# Speed: 1.2ms preprocess, 13.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 15.2ms
# Speed: 1.3ms preprocess, 15.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 13.8ms
# Speed: 1.0ms preprocess, 13.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 11.8ms
# Speed: 2.0ms preprocess, 11.8ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 13.4ms
# Speed: 1.0ms preprocess, 13.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 13.1ms
# Speed: 1.0ms preprocess, 13.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 11.7ms
# Speed: 1.5ms preprocess, 11.7ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 11.8ms
# Speed: 2.5ms preprocess, 11.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 13.2ms
# Speed: 2.4ms preprocess, 13.2ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 12.9ms
# Speed: 3.0ms preprocess, 12.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 15.3ms
# Speed: 2.5ms preprocess, 15.3ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 12.5ms
# Speed: 1.0ms preprocess, 12.5ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 13.1ms
# Speed: 1.0ms preprocess, 13.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 14.0ms
# Speed: 1.0ms preprocess, 14.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 12.6ms
# Speed: 1.0ms preprocess, 12.6ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 12.0ms
# Speed: 1.5ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 12.7ms
# Speed: 1.1ms preprocess, 12.7ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 13.0ms
# Speed: 1.0ms preprocess, 13.0ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 13.3ms
# Speed: 1.3ms preprocess, 13.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 12.9ms
# Speed: 2.3ms preprocess, 12.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 25.5ms
# Speed: 4.0ms preprocess, 25.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 26.1ms
# Speed: 3.2ms preprocess, 26.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 28.0ms
# Speed: 2.2ms preprocess, 28.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 14.2ms
# Speed: 2.0ms preprocess, 14.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 13.5ms
# Speed: 1.0ms preprocess, 13.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 12.0ms
# Speed: 1.9ms preprocess, 12.0ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 15.5ms
# Speed: 2.0ms preprocess, 15.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 13.2ms
# Speed: 1.4ms preprocess, 13.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 13.9ms
# Speed: 1.4ms preprocess, 13.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 13.4ms
# Speed: 1.5ms preprocess, 13.4ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 11.9ms
# Speed: 1.4ms preprocess, 11.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 12.0ms
# Speed: 3.0ms preprocess, 12.0ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 13.2ms
# Speed: 1.5ms preprocess, 13.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 16.2ms
# Speed: 1.2ms preprocess, 16.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 12.6ms
# Speed: 2.0ms preprocess, 12.6ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 13.5ms
# Speed: 2.0ms preprocess, 13.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 18.4ms
# Speed: 2.8ms preprocess, 18.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 12.5ms
# Speed: 1.4ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 13.3ms
# Speed: 1.0ms preprocess, 13.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 12.3ms
# Speed: 1.0ms preprocess, 12.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 13.2ms
# Speed: 1.3ms preprocess, 13.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 13.4ms
# Speed: 2.0ms preprocess, 13.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 12.9ms
# Speed: 1.0ms preprocess, 12.9ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 13.3ms
# Speed: 1.0ms preprocess, 13.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 12.7ms
# Speed: 1.0ms preprocess, 12.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 12.6ms
# Speed: 1.0ms preprocess, 12.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 12.9ms
# Speed: 2.3ms preprocess, 12.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 12.2ms
# Speed: 2.0ms preprocess, 12.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 12.3ms
# Speed: 1.0ms preprocess, 12.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 12.3ms
# Speed: 2.1ms preprocess, 12.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 12.5ms
# Speed: 2.4ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 12.9ms
# Speed: 1.0ms preprocess, 12.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 11.8ms
# Speed: 1.0ms preprocess, 11.8ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 16.0ms
# Speed: 2.0ms preprocess, 16.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 13.3ms
# Speed: 1.4ms preprocess, 13.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 12.2ms
# Speed: 1.4ms preprocess, 12.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 12.5ms
# Speed: 1.3ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 28.5ms
# Speed: 2.9ms preprocess, 28.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 29.1ms
# Speed: 2.0ms preprocess, 29.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 29.4ms
# Speed: 1.8ms preprocess, 29.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 16.5ms
# Speed: 2.2ms preprocess, 16.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 12.6ms
# Speed: 1.4ms preprocess, 12.6ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 13.5ms
# Speed: 1.0ms preprocess, 13.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 14.5ms
# Speed: 3.0ms preprocess, 14.5ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 17.0ms
# Speed: 2.0ms preprocess, 17.0ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 17.0ms
# Speed: 1.2ms preprocess, 17.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 13.5ms
# Speed: 0.5ms preprocess, 13.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 15.3ms
# Speed: 1.0ms preprocess, 15.3ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 12.7ms
# Speed: 1.7ms preprocess, 12.7ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 13.5ms
# Speed: 1.0ms preprocess, 13.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 14.9ms
# Speed: 2.3ms preprocess, 14.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 13.5ms
# Speed: 1.5ms preprocess, 13.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 14.5ms
# Speed: 1.0ms preprocess, 14.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 12.5ms
# Speed: 1.0ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 15.5ms
# Speed: 1.0ms preprocess, 15.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 13.0ms
# Speed: 1.0ms preprocess, 13.0ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 13.8ms
# Speed: 2.1ms preprocess, 13.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 13.0ms
# Speed: 1.0ms preprocess, 13.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 13.4ms
# Speed: 1.0ms preprocess, 13.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 12.5ms
# Speed: 2.0ms preprocess, 12.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 12.8ms
# Speed: 2.0ms preprocess, 12.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 13.5ms
# Speed: 1.5ms preprocess, 13.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 14.2ms
# Speed: 2.1ms preprocess, 14.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 14.8ms
# Speed: 1.8ms preprocess, 14.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 13.6ms
# Speed: 1.5ms preprocess, 13.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 14.5ms
# Speed: 2.0ms preprocess, 14.5ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 13.2ms
# Speed: 2.0ms preprocess, 13.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 14.2ms
# Speed: 1.5ms preprocess, 14.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 12.4ms
# Speed: 1.0ms preprocess, 12.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 13.5ms
# Speed: 2.2ms preprocess, 13.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 13.3ms
# Speed: 1.0ms preprocess, 13.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 13.0ms
# Speed: 2.6ms preprocess, 13.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 12.5ms
# Speed: 1.5ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 14.6ms
# Speed: 1.0ms preprocess, 14.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 12.2ms
# Speed: 1.5ms preprocess, 12.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 12.5ms
# Speed: 1.0ms preprocess, 12.5ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 15.3ms
# Speed: 1.0ms preprocess, 15.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 16.0ms
# Speed: 2.3ms preprocess, 16.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 13.7ms
# Speed: 1.5ms preprocess, 13.7ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 14.3ms
# Speed: 0.5ms preprocess, 14.3ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 16.1ms
# Speed: 2.0ms preprocess, 16.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 15.4ms
# Speed: 1.0ms preprocess, 15.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 14.5ms
# Speed: 1.1ms preprocess, 14.5ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 15.6ms
# Speed: 1.4ms preprocess, 15.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 20.0ms
# Speed: 2.2ms preprocess, 20.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 18.8ms
# Speed: 2.5ms preprocess, 18.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 16.6ms
# Speed: 1.4ms preprocess, 16.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 15.3ms
# Speed: 1.0ms preprocess, 15.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 14.8ms
# Speed: 2.4ms preprocess, 14.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 18.0ms
# Speed: 1.0ms preprocess, 18.0ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 17.1ms
# Speed: 1.0ms preprocess, 17.1ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 15.4ms
# Speed: 1.4ms preprocess, 15.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 15.6ms
# Speed: 1.2ms preprocess, 15.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 salt, 15.8ms
# Speed: 1.5ms preprocess, 15.8ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bread, 34.2ms
# Speed: 2.5ms preprocess, 34.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 80.0ms
# Speed: 3.8ms preprocess, 80.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 72.9ms
# Speed: 4.2ms preprocess, 72.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 48.3ms
# Speed: 3.2ms preprocess, 48.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 9.8ms
# Speed: 1.0ms preprocess, 9.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 9.9ms
# Speed: 1.0ms preprocess, 9.9ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 9.0ms
# Speed: 2.5ms preprocess, 9.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 10.2ms
# Speed: 1.0ms preprocess, 10.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 8.5ms
# Speed: 1.4ms preprocess, 8.5ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 9.1ms
# Speed: 1.0ms preprocess, 9.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 9.3ms
# Speed: 1.0ms preprocess, 9.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 8.0ms
# Speed: 1.5ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 9.3ms
# Speed: 1.0ms preprocess, 9.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 14.5ms
# Speed: 2.3ms preprocess, 14.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 8.5ms
# Speed: 1.5ms preprocess, 8.5ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 8.5ms
# Speed: 1.0ms preprocess, 8.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 9.1ms
# Speed: 1.0ms preprocess, 9.1ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 10.5ms
# Speed: 1.0ms preprocess, 10.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 8.4ms
# Speed: 2.7ms preprocess, 8.4ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 9.5ms
# Speed: 1.0ms preprocess, 9.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 9.4ms
# Speed: 1.0ms preprocess, 9.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bread, 13.6ms
# Speed: 2.0ms preprocess, 13.6ms inference, 12.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 30.4ms
# Speed: 2.6ms preprocess, 30.4ms inference, 3.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 31.0ms
# Speed: 1.5ms preprocess, 31.0ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 30.3ms
# Speed: 1.6ms preprocess, 30.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 28.5ms
# Speed: 2.4ms preprocess, 28.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 27.8ms
# Speed: 2.2ms preprocess, 27.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 28.6ms
# Speed: 1.0ms preprocess, 28.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 15.9ms
# Speed: 1.5ms preprocess, 15.9ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 15.2ms
# Speed: 2.0ms preprocess, 15.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 17.5ms
# Speed: 1.0ms preprocess, 17.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 14.4ms
# Speed: 2.0ms preprocess, 14.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 13.9ms
# Speed: 1.0ms preprocess, 13.9ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 15.5ms
# Speed: 2.0ms preprocess, 15.5ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 16.7ms
# Speed: 2.5ms preprocess, 16.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 13.7ms
# Speed: 2.0ms preprocess, 13.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 13.5ms
# Speed: 2.0ms preprocess, 13.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 15.9ms
# Speed: 1.0ms preprocess, 15.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 14.8ms
# Speed: 1.0ms preprocess, 14.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 14.4ms
# Speed: 1.0ms preprocess, 14.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 15.6ms
# Speed: 1.0ms preprocess, 15.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 15.3ms
# Speed: 2.0ms preprocess, 15.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 14.5ms
# Speed: 1.4ms preprocess, 14.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 14.7ms
# Speed: 1.0ms preprocess, 14.7ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 14.6ms
# Speed: 2.0ms preprocess, 14.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 14.0ms
# Speed: 1.5ms preprocess, 14.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 15.6ms
# Speed: 1.0ms preprocess, 15.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 13.9ms
# Speed: 1.0ms preprocess, 13.9ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 14.4ms
# Speed: 1.0ms preprocess, 14.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 14.0ms
# Speed: 1.0ms preprocess, 14.0ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 15.2ms
# Speed: 1.3ms preprocess, 15.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 13.6ms
# Speed: 2.3ms preprocess, 13.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 15.5ms
# Speed: 2.5ms preprocess, 15.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bread, 15.5ms
# Speed: 1.0ms preprocess, 15.5ms inference, 5.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 33.5ms
# Speed: 3.0ms preprocess, 33.5ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 34.0ms
# Speed: 2.0ms preprocess, 34.0ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 36.6ms
# Speed: 2.0ms preprocess, 36.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 31.5ms
# Speed: 2.1ms preprocess, 31.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 29.1ms
# Speed: 2.5ms preprocess, 29.1ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 29.5ms
# Speed: 1.2ms preprocess, 29.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 25.9ms
# Speed: 3.0ms preprocess, 25.9ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 26.8ms
# Speed: 3.4ms preprocess, 26.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 26.5ms
# Speed: 2.3ms preprocess, 26.5ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 15.8ms
# Speed: 2.0ms preprocess, 15.8ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 14.0ms
# Speed: 1.1ms preprocess, 14.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 13.5ms
# Speed: 2.0ms preprocess, 13.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 13.8ms
# Speed: 1.8ms preprocess, 13.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 18.4ms
# Speed: 1.0ms preprocess, 18.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 14.1ms
# Speed: 2.0ms preprocess, 14.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 13.2ms
# Speed: 2.0ms preprocess, 13.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 13.6ms
# Speed: 1.4ms preprocess, 13.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bread, 14.0ms
# Speed: 1.4ms preprocess, 14.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 13.9ms
# Speed: 0.0ms preprocess, 13.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 14.2ms
# Speed: 1.0ms preprocess, 14.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 16.2ms
# Speed: 1.0ms preprocess, 16.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 16.9ms
# Speed: 1.0ms preprocess, 16.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 13.6ms
# Speed: 1.6ms preprocess, 13.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 15.1ms
# Speed: 1.0ms preprocess, 15.1ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 29.1ms
# Speed: 3.0ms preprocess, 29.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 27.4ms
# Speed: 2.4ms preprocess, 27.4ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 27.8ms
# Speed: 2.4ms preprocess, 27.8ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 17.0ms
# Speed: 3.5ms preprocess, 17.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 15.5ms
# Speed: 1.5ms preprocess, 15.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 15.5ms
# Speed: 1.0ms preprocess, 15.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 14.0ms
# Speed: 1.0ms preprocess, 14.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 13.9ms
# Speed: 1.0ms preprocess, 13.9ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 15.1ms
# Speed: 1.0ms preprocess, 15.1ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 13.1ms
# Speed: 1.2ms preprocess, 13.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 15.7ms
# Speed: 1.4ms preprocess, 15.7ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 19.5ms
# Speed: 2.0ms preprocess, 19.5ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 14.1ms
# Speed: 1.0ms preprocess, 14.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 13.8ms
# Speed: 1.5ms preprocess, 13.8ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 13.5ms
# Speed: 1.0ms preprocess, 13.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 13.4ms
# Speed: 2.0ms preprocess, 13.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 15.7ms
# Speed: 1.5ms preprocess, 15.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 13.8ms
# Speed: 1.0ms preprocess, 13.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 13.6ms
# Speed: 2.4ms preprocess, 13.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 16.8ms
# Speed: 1.0ms preprocess, 16.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 13.5ms
# Speed: 1.0ms preprocess, 13.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 14.1ms
# Speed: 1.0ms preprocess, 14.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 14.0ms
# Speed: 1.0ms preprocess, 14.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 15.5ms
# Speed: 1.0ms preprocess, 15.5ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 13.8ms
# Speed: 1.5ms preprocess, 13.8ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 13.7ms
# Speed: 1.5ms preprocess, 13.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 18.8ms
# Speed: 1.1ms preprocess, 18.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 13.2ms
# Speed: 1.5ms preprocess, 13.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 14.5ms
# Speed: 1.5ms preprocess, 14.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 13.5ms
# Speed: 1.0ms preprocess, 13.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 15.1ms
# Speed: 1.0ms preprocess, 15.1ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 13.9ms
# Speed: 1.0ms preprocess, 13.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 14.2ms
# Speed: 1.0ms preprocess, 14.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 14.2ms
# Speed: 1.2ms preprocess, 14.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 14.0ms
# Speed: 1.0ms preprocess, 14.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 13.5ms
# Speed: 2.3ms preprocess, 13.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 14.0ms
# Speed: 2.5ms preprocess, 14.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 14.3ms
# Speed: 3.0ms preprocess, 14.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 13.9ms
# Speed: 1.0ms preprocess, 13.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 15.6ms
# Speed: 1.5ms preprocess, 15.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 14.8ms
# Speed: 2.1ms preprocess, 14.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 15.0ms
# Speed: 1.2ms preprocess, 15.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 14.6ms
# Speed: 1.0ms preprocess, 14.6ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 16.0ms
# Speed: 1.0ms preprocess, 16.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 15.8ms
# Speed: 1.5ms preprocess, 15.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 16.7ms
# Speed: 1.5ms preprocess, 16.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 15.6ms
# Speed: 2.1ms preprocess, 15.6ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 16.1ms
# Speed: 2.0ms preprocess, 16.1ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 16.9ms
# Speed: 1.0ms preprocess, 16.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 16.0ms
# Speed: 1.0ms preprocess, 16.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 15.6ms
# Speed: 2.5ms preprocess, 15.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 18.0ms
# Speed: 2.1ms preprocess, 18.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 17.5ms
# Speed: 1.0ms preprocess, 17.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 16.1ms
# Speed: 1.0ms preprocess, 16.1ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 16.4ms
# Speed: 2.4ms preprocess, 16.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 15.6ms
# Speed: 1.0ms preprocess, 15.6ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 16.0ms
# Speed: 2.0ms preprocess, 16.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 16.0ms
# Speed: 1.3ms preprocess, 16.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 16.3ms
# Speed: 2.0ms preprocess, 16.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 29.5ms
# Speed: 2.0ms preprocess, 29.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 29.5ms
# Speed: 3.1ms preprocess, 29.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 29.5ms
# Speed: 2.3ms preprocess, 29.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 14.1ms
# ...
#
# 0: 480x640 (no detections), 12.9ms
# Speed: 2.0ms preprocess, 12.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 13.3ms
# Speed: 1.0ms preprocess, 13.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 13.2ms
# Speed: 2.0ms preprocess, 13.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 12.9ms
# Speed: 1.0ms preprocess, 12.9ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 14.0ms
# Speed: 1.0ms preprocess, 14.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 12.7ms
# Speed: 1.0ms preprocess, 12.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 12.8ms
# Speed: 1.3ms preprocess, 12.8ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 14.5ms
# Speed: 2.5ms preprocess, 14.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 12.7ms
# Speed: 1.0ms preprocess, 12.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 13.1ms
# Speed: 1.0ms preprocess, 13.1ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 12.5ms
# Speed: 2.0ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 26.9ms
# Speed: 1.2ms preprocess, 26.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 27.3ms
# Speed: 3.4ms preprocess, 27.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 26.6ms
# Speed: 3.4ms preprocess, 26.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 21.8ms
# Speed: 2.1ms preprocess, 21.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 12.6ms
# Speed: 2.1ms preprocess, 12.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 12.5ms
# Speed: 2.0ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 13.6ms
# Speed: 1.5ms preprocess, 13.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 12.5ms
# Speed: 2.1ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 12.4ms
# Speed: 1.0ms preprocess, 12.4ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 13.5ms
# Speed: 1.1ms preprocess, 13.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 13.6ms
# Speed: 1.0ms preprocess, 13.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 12.7ms
# Speed: 1.0ms preprocess, 12.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 12.5ms
# Speed: 1.0ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 12.6ms
# Speed: 1.5ms preprocess, 12.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 12.6ms
# Speed: 1.2ms preprocess, 12.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 12.6ms
# Speed: 1.3ms preprocess, 12.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 13.4ms
# Speed: 1.2ms preprocess, 13.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 12.5ms
# Speed: 2.0ms preprocess, 12.5ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 13.8ms
# Speed: 1.0ms preprocess, 13.8ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 13.1ms
# Speed: 1.5ms preprocess, 13.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 12.5ms
# Speed: 2.1ms preprocess, 12.5ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 13.0ms
# Speed: 1.0ms preprocess, 13.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 12.6ms
# Speed: 1.5ms preprocess, 12.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 16.2ms
# Speed: 2.0ms preprocess, 16.2ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 12.4ms
# Speed: 1.0ms preprocess, 12.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 12.9ms
# Speed: 1.5ms preprocess, 12.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# WARNING  'source' is missing. Using 'source=E:\Anaconda\Lib\site-packages\ultralytics\assets'.
#
# image 1/2 E:\Anaconda\Lib\site-packages\ultralytics\assets\bus.jpg: 640x480 (no detections), 56.7ms
# image 2/2 E:\Anaconda\Lib\site-packages\ultralytics\assets\zidane.jpg: 384x640 (no detections), 64.5ms
# Speed: 2.0ms preprocess, 60.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  'source' is missing. Using 'source=E:\Anaconda\Lib\site-packages\ultralytics\assets'.
#
# image 1/2 E:\Anaconda\Lib\site-packages\ultralytics\assets\bus.jpg: 640x480 (no detections), 15.4ms
# image 2/2 E:\Anaconda\Lib\site-packages\ultralytics\assets\zidane.jpg: 384x640 (no detections), 27.9ms
# Speed: 2.7ms preprocess, 21.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  'source' is missing. Using 'source=E:\Anaconda\Lib\site-packages\ultralytics\assets'.
#
# image 1/2 E:\Anaconda\Lib\site-packages\ultralytics\assets\bus.jpg: 640x480 (no detections), 36.1ms
# image 2/2 E:\Anaconda\Lib\site-packages\ultralytics\assets\zidane.jpg: 384x640 (no detections), 35.7ms
# Speed: 3.0ms preprocess, 35.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  'source' is missing. Using 'source=E:\Anaconda\Lib\site-packages\ultralytics\assets'.
#
# image 1/2 E:\Anaconda\Lib\site-packages\ultralytics\assets\bus.jpg: 640x480 (no detections), 40.8ms
# image 2/2 E:\Anaconda\Lib\site-packages\ultralytics\assets\zidane.jpg: 384x640 (no detections), 56.5ms
# Speed: 3.8ms preprocess, 48.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  'source' is missing. Using 'source=E:\Anaconda\Lib\site-packages\ultralytics\assets'.
#
# image 1/2 E:\Anaconda\Lib\site-packages\ultralytics\assets\bus.jpg: 640x480 (no detections), 68.3ms
# image 2/2 E:\Anaconda\Lib\site-packages\ultralytics\assets\zidane.jpg: 384x640 (no detections), 56.8ms
# Speed: 4.3ms preprocess, 62.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  'source' is missing. Using 'source=E:\Anaconda\Lib\site-packages\ultralytics\assets'.
#
# image 1/2 E:\Anaconda\Lib\site-packages\ultralytics\assets\bus.jpg: 640x480 (no detections), 69.3ms
# image 2/2 E:\Anaconda\Lib\site-packages\ultralytics\assets\zidane.jpg: 384x640 (no detections), 56.7ms
# Speed: 4.0ms preprocess, 63.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  'source' is missing. Using 'source=E:\Anaconda\Lib\site-packages\ultralytics\assets'.
#
# image 1/2 E:\Anaconda\Lib\site-packages\ultralytics\assets\bus.jpg: 640x480 (no detections), 68.6ms
# image 2/2 E:\Anaconda\Lib\site-packages\ultralytics\assets\zidane.jpg: 384x640 (no detections), 58.5ms
# Speed: 4.4ms preprocess, 63.6ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  'source' is missing. Using 'source=E:\Anaconda\Lib\site-packages\ultralytics\assets'.
#
# image 1/2 E:\Anaconda\Lib\site-packages\ultralytics\assets\bus.jpg: 640x480 (no detections), 68.4ms
# image 2/2 E:\Anaconda\Lib\site-packages\ultralytics\assets\zidane.jpg: 384x640 (no detections), 57.1ms
# Speed: 4.4ms preprocess, 62.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  'source' is missing. Using 'source=E:\Anaconda\Lib\site-packages\ultralytics\assets'.
#
# image 1/2 E:\Anaconda\Lib\site-packages\ultralytics\assets\bus.jpg: 640x480 (no detections), 69.0ms
# image 2/2 E:\Anaconda\Lib\site-packages\ultralytics\assets\zidane.jpg: 384x640 (no detections), 56.6ms
# Speed: 4.8ms preprocess, 62.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  'source' is missing. Using 'source=E:\Anaconda\Lib\site-packages\ultralytics\assets'.
#
# image 1/2 E:\Anaconda\Lib\site-packages\ultralytics\assets\bus.jpg: 640x480 (no detections), 68.9ms
# image 2/2 E:\Anaconda\Lib\site-packages\ultralytics\assets\zidane.jpg: 384x640 (no detections), 55.8ms
# Speed: 4.3ms preprocess, 62.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  'source' is missing. Using 'source=E:\Anaconda\Lib\site-packages\ultralytics\assets'.
#
# image 1/2 E:\Anaconda\Lib\site-packages\ultralytics\assets\bus.jpg: 640x480 (no detections), 69.1ms
# image 2/2 E:\Anaconda\Lib\site-packages\ultralytics\assets\zidane.jpg: 384x640 (no detections), 56.2ms
# Speed: 4.4ms preprocess, 62.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  'source' is missing. Using 'source=E:\Anaconda\Lib\site-packages\ultralytics\assets'.
#
# image 1/2 E:\Anaconda\Lib\site-packages\ultralytics\assets\bus.jpg: 640x480 (no detections), 71.3ms
# image 2/2 E:\Anaconda\Lib\site-packages\ultralytics\assets\zidane.jpg: 384x640 (no detections), 57.3ms
# Speed: 4.3ms preprocess, 64.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  'source' is missing. Using 'source=E:\Anaconda\Lib\site-packages\ultralytics\assets'.
#
# image 1/2 E:\Anaconda\Lib\site-packages\ultralytics\assets\bus.jpg: 640x480 (no detections), 70.7ms
# image 2/2 E:\Anaconda\Lib\site-packages\ultralytics\assets\zidane.jpg: 384x640 (no detections), 60.0ms
# Speed: 4.5ms preprocess, 65.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  'source' is missing. Using 'source=E:\Anaconda\Lib\site-packages\ultralytics\assets'.
#
# image 1/2 E:\Anaconda\Lib\site-packages\ultralytics\assets\bus.jpg: 640x480 (no detections), 69.3ms
# image 2/2 E:\Anaconda\Lib\site-packages\ultralytics\assets\zidane.jpg: 384x640 (no detections), 56.5ms
# Speed: 3.8ms preprocess, 62.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  'source' is missing. Using 'source=E:\Anaconda\Lib\site-packages\ultralytics\assets'.
#
# image 1/2 E:\Anaconda\Lib\site-packages\ultralytics\assets\bus.jpg: 640x480 (no detections), 68.6ms
# image 2/2 E:\Anaconda\Lib\site-packages\ultralytics\assets\zidane.jpg: 384x640 (no detections), 57.3ms
# Speed: 4.5ms preprocess, 62.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  'source' is missing. Using 'source=E:\Anaconda\Lib\site-packages\ultralytics\assets'.
#
# image 1/2 E:\Anaconda\Lib\site-packages\ultralytics\assets\bus.jpg: 640x480 (no detections), 68.3ms
# image 2/2 E:\Anaconda\Lib\site-packages\ultralytics\assets\zidane.jpg: 384x640 (no detections), 55.9ms
# Speed: 3.7ms preprocess, 62.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  'source' is missing. Using 'source=E:\Anaconda\Lib\site-packages\ultralytics\assets'.
#
# image 1/2 E:\Anaconda\Lib\site-packages\ultralytics\assets\bus.jpg: 640x480 (no detections), 68.8ms
# image 2/2 E:\Anaconda\Lib\site-packages\ultralytics\assets\zidane.jpg: 384x640 (no detections), 57.4ms
# Speed: 4.3ms preprocess, 63.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  'source' is missing. Using 'source=E:\Anaconda\Lib\site-packages\ultralytics\assets'.
#
# image 1/2 E:\Anaconda\Lib\site-packages\ultralytics\assets\bus.jpg: 640x480 (no detections), 69.6ms
# image 2/2 E:\Anaconda\Lib\site-packages\ultralytics\assets\zidane.jpg: 384x640 (no detections), 56.1ms
# Speed: 3.3ms preprocess, 62.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  'source' is missing. Using 'source=E:\Anaconda\Lib\site-packages\ultralytics\assets'.
#
# image 1/2 E:\Anaconda\Lib\site-packages\ultralytics\assets\bus.jpg: 640x480 (no detections), 68.7ms
# image 2/2 E:\Anaconda\Lib\site-packages\ultralytics\assets\zidane.jpg: 384x640 (no detections), 56.4ms
# Speed: 4.0ms preprocess, 62.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  'source' is missing. Using 'source=E:\Anaconda\Lib\site-packages\ultralytics\assets'.
#
# image 1/2 E:\Anaconda\Lib\site-packages\ultralytics\assets\bus.jpg: 640x480 (no detections), 69.4ms
# image 2/2 E:\Anaconda\Lib\site-packages\ultralytics\assets\zidane.jpg: 384x640 (no detections), 56.5ms
# Speed: 4.5ms preprocess, 63.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# WARNING  'source' is missing. Using 'source=E:\Anaconda\Lib\site-packages\ultralytics\assets'.
#
# image 1/2 E:\Anaconda\Lib\site-packages\ultralytics\assets\bus.jpg: 640x480 (no detections), 68.7ms
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 11
#       7 while True:
#       9         ret, frame = cap.read()
# ---> 11         results = model(frame, show=True)[0]
#      13         for result in results.boxes.data.tolist():
#      14             x1, y1, x2, y2, score, class_id = result
#
# File e:\Anaconda\Lib\site-packages\ultralytics\engine\model.py:101, in Model.__call__(self, source, stream, **kwargs)
#      99 def __call__(self, source=None, stream=False, **kwargs):
#     100     """Calls the 'predict' function with given arguments to perform object detection."""
# --> 101     return self.predict(source, stream, **kwargs)
#
# File e:\Anaconda\Lib\site-packages\ultralytics\engine\model.py:242, in Model.predict(self, source, stream, predictor, **kwargs)
#     240 if prompts and hasattr(self.predictor, 'set_prompts'):  # for SAM-type models
#     241     self.predictor.set_prompts(prompts)
# --> 242 return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#
# File e:\Anaconda\Lib\site-packages\ultralytics\engine\predictor.py:196, in BasePredictor.__call__(self, source, model, stream, *args, **kwargs)
#     194     return self.stream_inference(source, model, *args, **kwargs)
#     195 else:
# --> 196     return list(self.stream_inference(source, model, *args, **kwargs))
#
# File e:\Anaconda\Lib\site-packages\torch\utils\_contextlib.py:56, in _wrap_generator.<locals>.generator_context(*args, **kwargs)
#      53         else:
#      54             # Pass the last request to the generator and get its response
#      55             with ctx_factory():
# ---> 56                 response = gen.send(request)
#      58 # We let the exceptions raised above by the generator's `.throw` or
#      59 # `.send` methods bubble up to our caller, except for StopIteration
#      60 except StopIteration as e:
#      61     # The generator informed us that it is done: take whatever its
#      62     # returned value (if any) was and indicate that we're done too
#      63     # by returning it (see docs for python's return-statement).
#
# File e:\Anaconda\Lib\site-packages\ultralytics\engine\predictor.py:282, in BasePredictor.stream_inference(self, source, model, *args, **kwargs)
#     280     self.results[i].save_dir = self.save_dir.__str__()
#     281 if self.args.show and self.plotted_img is not None:
# --> 282     self.show(p)
#     283 if self.args.save and self.plotted_img is not None:
#     284     self.save_preds(vid_cap, i, str(self.save_dir / p.name))
#
# File e:\Anaconda\Lib\site-packages\ultralytics\engine\predictor.py:331, in BasePredictor.show(self, p)
#     329     cv2.resizeWindow(str(p), im0.shape[1], im0.shape[0])
#     330 cv2.imshow(str(p), im0)
# --> 331 cv2.waitKey(500 if self.batch[3].startswith('image') else 1)
#
# KeyboardInterrupt:

# %%
cap.release()
cv2.destroyAllWindows()
